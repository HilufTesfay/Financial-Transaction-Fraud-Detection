# %%
import pandas as pd
import logging
import os
import sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from src.utils.helper import get_root_path,setup_logger
from src.data.analysis import load_data,clean_and_preprocess_data
setup_logger("main")
logger=logging.getLogger(__name__)
root_path=get_root_path()

# %%
credit_path=root_path /"data" /"raw" /"creditcard.csv"
fraud_path=root_path / "data" /"raw" /"Fraud_Data.csv"
ip_path=root_path /"data"/"raw"/ "IpAddress_to_Country.csv"

credit_df=load_data(credit_path)
fraud_df=load_data(fraud_path)
ip_df=load_data(ip_path)

# %%
print("shape:",fraud_df.shape)
print(f"columns: {list(fraud_df.columns)}")
fraud_df.head()
# Out:
# shape: (151112, 11)
# columns: ['user_id', 'signup_time', 'purchase_time', 'purchase_value', 'device_id', 'source', 'browser', 'sex', 'age', 'ip_address', 'class']
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
print("shape:",credit_df.shape)
print(f"columns: {list(credit_df.columns)}")
credit_df.head()
# Out:
# shape: (284807, 31)
# columns: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# ...

# %%
print("shape:",ip_df.shape)
print(f"columns: {list(ip_df.columns)}")
ip_df.head()
# Out:
# shape: (138846, 3)
# columns: ['lower_bound_ip_address', 'upper_bound_ip_address', 'country']
#    lower_bound_ip_address  upper_bound_ip_address    country
# 0              16777216.0                16777471  Australia
# 1              16777472.0                16777727      China
# 2              16777728.0                16778239      China
# 3              16778240.0                16779263  Australia
# 4              16779264.0                16781311      China

# %% [markdown]
# ## data preparartion

# %%
processed_path=root_path /"data"/"processed"
cleaned_cridit_df=clean_and_preprocess_data(credit_df)
cleaned_fraud_df=clean_and_preprocess_data(fraud_df)
cleaned_ip_df=clean_and_preprocess_data(ip_df)

cleaned_cridit_df.to_csv(processed_path/"creditcard.csv" ,index=False)
cleaned_fraud_df.to_csv(processed_path/"fraud.csv" ,index=False)
cleaned_ip_df.to_csv(processed_path/"ip.csv" ,index=False)
# Out:
# 2025-08-15 15:24:06,688 - src.data.analysis - INFO - No numerical columns with missing values found.
# 2025-08-15 15:24:06,690 - src.data.analysis - INFO -   No categorical columns with missing values found.
# 2025-08-15 15:24:06,693 - src.data.analysis - INFO - DataFrame shape after handling missing values: (284807, 31)
# 2025-08-15 15:24:06,695 - src.data.analysis - INFO -
#  __ Removing Duplicates:
# 2025-08-15 15:24:08,423 - src.data.analysis - INFO -   Removed 1081 duplicate rows.
# 2025-08-15 15:24:08,425 - src.data.analysis - INFO - DataFrame shape after removing duplicates: (283726, 31)
# 2025-08-15 15:24:08,427 - src.data.analysis - INFO -
# --- Data Cleaning and Preprocessing Complete ---
# 2025-08-15 15:24:08,429 - src.data.analysis - INFO - Final DataFrame shape: (283726, 31)
# 2025-08-15 15:24:08,621 - src.data.analysis - INFO - Column 'Time' successfully converted to datetime.
# ...
